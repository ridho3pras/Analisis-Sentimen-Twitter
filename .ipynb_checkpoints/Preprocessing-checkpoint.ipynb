# %% [markdown]
# # Tahap Pre Porcessing Data
#
# Pada tahap ini dilakukan pra pemerosesan data untuk membersihkan data dari gangguan noise

# %%
import pandas as pd 
import csv
import ast
import string 
import re #regex library
import preprocessor as p
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('corpus')
from nltk.tokenize import word_tokenize 
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter
# Out:
# [nltk_data] Downloading package punkt to C:\Users\RIDHO-
# [nltk_data]     PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\RIDHO-
# [nltk_data]     PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Error loading corpus: Package 'corpus' not found in index

# %%
# membaca data hasil crawling dan labeling
data_twt = pd.read_csv("dataset/dataset-labeling.csv")

# %%
data_twt
# Out:
#             username       tweetcreatedts  \
# 0           taphodit  2021-10-26 23:55:21
# 1           L94KJISS  2021-10-26 23:52:56
# 2           jjnanney  2021-10-26 23:45:18
# 3      Vinaa32383695  2021-10-26 23:41:07
# 4            schfess  2021-10-26 23:39:56
# ..               ...                  ...
# 995  enhypenaddicted  2021-10-23 01:42:25
# 996         shnsukei  2021-10-23 01:39:47
# 997           Drllny  2021-10-23 01:29:14
# 998      CHOl_TAEHUN  2021-10-23 01:27:46
# 999         jyonjaey  2021-10-23 01:22:45
#
#                                                  tweet  label_sentimen
# 0        ASTAGAAAA BARU INGET SEKARANG SEKOLAH OFFLINE              -1
# 1    Yg udh sekolah offline, lama lama bosan gsi se...              -1
# 2    @jinhwanchy Wah udah sekolah offline? Semangat...               1
# 3    @Fajri_UN1TY Haii juga, yuk yg sekolah offline...               1
# 4    Sch! Hai gais hari ini sender PTM untuk yg per...              -1
# ..                                                 ...             ...
# 995  Ya Tuhan, besok sekolah agama offline aku gama...              -1
# 996  @jegiannnnn__ bukan 0 sih, tapi udh mau zona i...               1
# 997  @CHOl_SAN_ @prkdlx Nanti pulang sekolah ya, ak...               0
# 998                        Males bgt sekolah offline😭😭              -1
# 999  @peachwzrl_ Bener banget :(. Aku dulu waktu ma...               0
#
# [1000 rows x 4 columns]

# %% [markdown]
# ## Case Folding

# %%
data_twt['tweet_cf'] = data_twt['tweet'].str.lower()

print('Case Folding Result : \n')
print(data_twt['tweet_cf'].head(5))
print('\n\n\n')
# Out:
# Case Folding Result :
#
# 0        astagaaaa baru inget sekarang sekolah offline
# 1    yg udh sekolah offline, lama lama bosan gsi se...
# 2    @jinhwanchy wah udah sekolah offline? semangat...
# 3    @fajri_un1ty haii juga, yuk yg sekolah offline...
# 4    sch! hai gais hari ini sender ptm untuk yg per...
# Name: tweet_cf, dtype: object

# %% [markdown]
# ## Tokenizing

# %%
def remove_tweet_special(text):
    # menghapus tab, new line, dan back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # menghapus non ASCII (emotikon, tulisan china, dll)
    text = text.encode('ascii', 'replace').decode('ascii')
    # menghapus mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # menghapus URL yg tidak lengkap
    return text.replace("http://", " ").replace("https://", " ")
                
data_twt['tweet_cf'] = data_twt['tweet_cf'].apply(remove_tweet_special)

#menghapus nomor
def remove_number(text):
    return  re.sub(r"\d+", "", text)

data_twt['tweet_cf'] = data_twt['tweet_cf'].apply(remove_number)

#menghapus tanda baca
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

data_twt['tweet_cf'] = data_twt['tweet_cf'].apply(remove_punctuation)

#menghapus spasi awal dan akhir
def remove_whitespace_LT(text):
    return text.strip()

data_twt['tweet_cf'] = data_twt['tweet_cf'].apply(remove_whitespace_LT)

#menghapus spasi yg dobel menjadi satu spasi
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

data_twt['tweet_cf'] = data_twt['tweet_cf'].apply(remove_whitespace_multiple)

# menghapus karakter tunggal
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

data_twt['tweet_clean'] = data_twt['tweet_cf'].apply(remove_singl_char)

def preprocessing_data(x):
    return p.clean(x)

data_twt['tweet_clean'] = data_twt['tweet_cf'].apply(preprocessing_data)

def tokenize_data(x):
    return p.tokenize(x)

data_twt['tweet_clean'] = data_twt['tweet_clean'].apply(tokenize_data)

# %%
alay_dict = pd.read_csv('kamus/kamusalay.csv', encoding='latin-1', header=None)
alay_dict = alay_dict.rename(columns={0: 'original', 
                                      1: 'replacement'})
alay_dict_map = dict(zip(alay_dict['original'], alay_dict['replacement']))
def normalize_alay(text):
    return ' '.join([alay_dict_map[word] if word in alay_dict_map else word for word in text.split(' ')])

data_twt['tweet_clean_alay'] = data_twt['tweet_clean'].apply(normalize_alay) 
data_twt.drop_duplicates(keep=False,inplace=True)

# %%
def word_tokenize_wrapper(text):
    return word_tokenize(text)

data_twt['tweet_token'] = data_twt['tweet_clean_alay'].apply(word_tokenize_wrapper)

# %% [markdown]
# ## Stopword Removal

# %%
from nltk.corpus import stopwords
print(set(stopwords.words('Indonesian')))
# Out:
# {'saatnya', 'demi', 'wahai', 'menjelaskan', 'atau', 'rupanya', 'disebutkannya', 'bersama-sama', 'berkali-kali', 'kurang', 'kan', 'mungkinkah', 'bagai', 'adanya', 'bersiap-siap', 'bersama', 'menyiapkan', 'dia', 'ataupun', 'kebetulan', 'enggak', 'setidaknya', 'segalanya', 'dibuat', 'setidak-tidaknya', 'diibaratkan', 'mengibaratkan', 'sekadarnya', 'tempat', 'malah', 'tinggi', 'seusai', 'bekerja', 'menunjuk', 'dimungkinkan', 'selamanya', 'terhadapnya', 'se', 'tiap', 'berjumlah', 'waktunya', 'kalaupun', 'begitulah', 'beginilah', 'cukup', 'tepat', 'tentang', 'tiba', 'pertama-tama', 'tanya', 'manalagi', 'melakukan', 'hanya', 'begitupun', 'empat', 'dimaksud', 'seluruh', 'begitu', 'ucapnya', 'dituturkannya', 'ibaratnya', 'depan', 'lanjut', 'mengatakannya', 'semata-mata', 'mengingatkan', 'nanti', 'selama-lamanya', 'dilihat', 'bermacam', 'ditanyakan', 'inginkan', 'sekecil', 'diibaratkannya', 'menunjukkan', 'tahu', 'sendirinya', 'masa', 'bukannya', 'meyakinkan', 'ungkapnya', 'menyatakan', 'memang', 'pula', 'kami', 'lalu', 'bermaksud', 'dirinya', 'satu', 'sepertinya', 'adalah', 'sekurangnya', 'datang', 'berakhirnya', 'hendaknya', 'dijelaskan', 'berapalah', 'diantara', 'ibu', 'khususnya', 'terutama', 'enggaknya', 'itulah', 'akankah', 'dikarenakan', 'tapi', 'sekurang-kurangnya', 'karena', 'dekat', 'menghendaki', 'berlalu', 'juga', 'dilakukan', 'menyebutkan', 'ternyata', 'agar', 'mampu', 'keduanya', 'adapun', 'pasti', 'memulai', 'sinilah', 'terlebih', 'atas', 'berlainan', 'dari', 'menaiki', 'hingga', 'cukupkah', 'mendatangkan', 'sepanjang', 'tiga', 'walau', 'kalian', 'tadinya', 'bukankah', 'akhiri', 'biasanya', 'keseluruhannya', 'bagaimanapun', 'belum', 'dipastikan', 'disampaikan', 'ditunjukkannya', 'keterlaluan', 'berujar', 'wong', 'berkata', 'diketahui', 'dan', 'asalkan', 'dimaksudnya', 'janganlah', 'nyaris', 'supaya', 'bertanya-tanya', 'suatu', 'toh', 'sekiranya', 'disini', 'diri', 'sesudahnya', 'beri', 'memberikan', 'nyatanya', 'ungkap', 'pantas', 'menurut', 'mempergunakan', 'bahkan', 'mengenai', 'semula', 'mengibaratkannya', 'seringnya', 'soal', 'dikatakan', 'sesaat', 'sedang', 'diperkirakan', 'sebanyak', 'kamu', 'menanyai', 'ingat-ingat', 'sangat', 'katanya', 'jangan', 'memperlihatkan', 'daripada', 'seseorang', 'boleh', 'meminta', 'diperlihatkan', 'mempersoalkan', 'menuturkan', 'berarti', 'menanti', 'akhir', 'menyampaikan', 'menyangkut', 'sama-sama', 'keseluruhan', 'cara', 'sewaktu', 'sambil', 'kalaulah', 'berupa', 'begitukah', 'waduh', 'memperbuat', 'sendirian', 'tentunya', 'setinggi', 'siapapun', 'bukanlah', 'antar', 'saja', 'balik', 'demikianlah', 'kala', 'minta', 'dimulainya', 'kalau', 'kini', 'diminta', 'menanya', 'serupa', 'terlalu', 'terkira', 'sebagai', 'makanya', 'pertanyakan', 'tak', 'tersebutlah', 'mulai', 'sampai', 'dimulai', 'kitalah', 'menginginkan', 'yaitu', 'sana', 'berapakah', 'menanyakan', 'olehnya', 'amat', 'berikutnya', 'diungkapkan', 'sekitarnya', 'tandasnya', 'mendapatkan', 'mengucapkan', 'pertama', 'kapan', 'disebutkan', 'tutur', 'kenapa', 'dituturkan', 'setibanya', 'bila', 'umum', 'katakan', 'merekalah', 'seolah', 'terhadap', 'macam', 'maka', 'benar', 'lagian', 'ataukah', 'bermacam-macam', 'awal', 'apalagi', 'lamanya', 'mengingat', 'panjang', 'ditujukan', 'dengan', 'seluruhnya', 'ditunjuki', 'tiba-tiba', 'akhirnya', 'akulah', 'tersebut', 'kelihatannya', 'sebelum', 'mengapa', 'dong', 'kesampaian', 'demikian', 'diperlukan', 'mempunyai', 'seperlunya', 'hari', 'dalam', 'makin', 'didatangkan', 'agaknya', 'baru', 'masihkah', 'bilakah', 'yakin', 'sini', 'tahun', 'jelaslah', 'dapat', 'buat', 'meskipun', 'sebagaimana', 'sesuatunya', 'tidakkah', 'semampu', 'ditandaskan', 'ia', 'perlunya', 'ketika', 'siapakah', 'betul', 'jumlah', 'sudahkah', 'mengetahui', 'semasa', 'bahwa', 'tunjuk', 'secara', 'apaan', 'memberi', 'sepantasnyalah', 'perlukah', 'sejumlah', 'jawab', 'lain', 'lima', 'jadilah', 'siapa', 'rata', 'seberapa', 'sebaik-baiknya', 'dini', 'berdatangan', 'hal', 'jauh', 'diingat', 'dialah', 'seenaknya', 'hendaklah', 'jad ...

# %%
# list stopword indonesia dari library nltk
list_stopwords = stopwords.words('indonesian')
print(len(list_stopwords))

# menambah stopword manual
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah', 'puan'])
len(list_stopwords)

# menambah stopword dari file luar
txt_stopword = pd.read_csv("kamus/stopword.csv", names= ["stopwords"], header = None)

# konversi stopword string ke list dan menambah stopword tambahan
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))
len(list_stopwords)
# ---------------------------------------------------------------------------------------

# konversi list to dictionary
list_stopwords = set(list_stopwords)


#menghapus stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

data_twt['tweet_stopword'] = data_twt['tweet_token'].apply(stopwords_removal) 


print(data_twt['tweet_stopword'])
# Out:
# 758
# 0                             [astaga, sekolah, offline]
# 1      [sekolah, offline, bosan, sekolah, offline, gu...
# 2                   [sekolah, offline, semangat, jojooo]
# 3      [unty, hai, yuk, sekolah, offline, kayak, sema...
# 4      [sch, hai, gais, sender, ptm, kali, sekolah, a...
#                              ...
# 995    [tuhan, besok, sekolah, agama, offline, presen...
# 996         [zona, hijau, semoga, dom, sekolah, offline]
# 997            [san, pulang, sekolah, mengajar, offline]
# 998                    [malas, banget, sekolah, offline]
# 999    [banget, sekolah, offline, sarapan, perut, ena...
# Name: tweet_stopword, Length: 1000, dtype: object

# %%
# normalisasi kata

def normalisasi(tweet):
    kamus_slangword = eval(open("kamus/combined_slang_words.txt").read()) # Membuka dictionary slangword
    pattern = re.compile(r'\b( ' + '|'.join (kamus_slangword.keys())+r')\b') # Search pola kata (contoh kpn -> kapan)
    content = []
    for kata in tweet:
        filteredSlang = pattern.sub(lambda x: kamus_slangword[x.group()],kata) # Replace slangword berdasarkan pola review yg telah ditentukan
        content.append(filteredSlang.lower())
    tweet = content
    return tweet
data_twt['tweet_normalisasi'] = data_twt['tweet_stopword'].apply(normalisasi)
print(data_twt['tweet_normalisasi'])
# Out:
# 0                             [astaga, sekolah, offline]
# 1      [sekolah, offline, bosan, sekolah, offline, sa...
# 2                   [sekolah, offline, semangat, jojooo]
# 3      [unty, hai, yuk, sekolah, offline, kayak, sema...
# 4      [sch, hai, teman teman, sender, ptm, kali, sek...
#                              ...
# 995    [tuhan, besok, sekolah, agama, offline, presen...
# 996         [zona, hijau, semoga, dom, sekolah, offline]
# 997            [san, pulang, sekolah, mengajar, offline]
# 998                    [malas, banget, sekolah, offline]
# 999    [banget, sekolah, offline, sarapan, perut, ena...
# Name: tweet_normalisasi, Length: 1000, dtype: object

# %% [markdown]
# ##  Stemming

# %%
# membuat stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in data_twt['tweet_normalisasi']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

data_twt['tweet_stemming'] = data_twt['tweet_normalisasi'].swifter.apply(get_stemmed_term)
print(data_twt['tweet_stemming'])
# Out:
# 2132
# ------------------------
# Pandas Apply:   0%|          | 0/1000 [00:00<?, ?it/s]
# 0                             [astaga, sekolah, offline]
# 1      [sekolah, offline, bosan, sekolah, offline, sa...
# 2                   [sekolah, offline, semangat, jojooo]
# 3      [unty, hai, yuk, sekolah, offline, kayak, sema...
# 4      [sch, hai, teman teman, sender, ptm, kali, sek...
#                              ...
# 995    [tuhan, besok, sekolah, agama, offline, presen...
# 996           [zona, hijau, moga, dom, sekolah, offline]
# 997                [san, pulang, sekolah, ajar, offline]
# 998                    [malas, banget, sekolah, offline]
# 999    [banget, sekolah, offline, sarap, perut, enak,...
# Name: tweet_stemming, Length: 1000, dtype: object

# %%
df = pd.DataFrame(data_twt)
df['tweet_stemming'] = df['tweet_stemming'].apply(str)

# %%
def join_text_list(texts):
    texts = ast.literal_eval(texts)
    return ' '.join([text for text in texts])
data_twt["tweet_bersih"] = data_twt["tweet_stemming"].apply(join_text_list)

# %%
data_twt
# Out:
#             username       tweetcreatedts  \
# 0           taphodit  2021-10-26 23:55:21
# 1           L94KJISS  2021-10-26 23:52:56
# 2           jjnanney  2021-10-26 23:45:18
# 3      Vinaa32383695  2021-10-26 23:41:07
# 4            schfess  2021-10-26 23:39:56
# ..               ...                  ...
# 995  enhypenaddicted  2021-10-23 01:42:25
# 996         shnsukei  2021-10-23 01:39:47
# 997           Drllny  2021-10-23 01:29:14
# 998      CHOl_TAEHUN  2021-10-23 01:27:46
# 999         jyonjaey  2021-10-23 01:22:45
#
#                                                  tweet  label_sentimen  \
# 0        ASTAGAAAA BARU INGET SEKARANG SEKOLAH OFFLINE              -1
# 1    Yg udh sekolah offline, lama lama bosan gsi se...              -1
# 2    @jinhwanchy Wah udah sekolah offline? Semangat...               1
# 3    @Fajri_UN1TY Haii juga, yuk yg sekolah offline...               1
# 4    Sch! Hai gais hari ini sender PTM untuk yg per...              -1
# ..                                                 ...             ...
# 995  Ya Tuhan, besok sekolah agama offline aku gama...              -1
# 996  @jegiannnnn__ bukan 0 sih, tapi udh mau zona i...               1
# 997  @CHOl_SAN_ @prkdlx Nanti pulang sekolah ya, ak...               0
# 998                        Males bgt sekolah offline😭😭              -1
# 999  @peachwzrl_ Bener banget :(. Aku dulu waktu ma...               0
#
#                                               tweet_cf  \
# 0        astagaaaa baru inget sekarang sekolah offline
# 1    yg udh sekolah offline lama lama bosan gsi sek...
# 2             wah udah sekolah offline semangat jojooo
# 3    unty haii juga yuk yg sekolah offline kayak ak...
# 4    sch hai gais hari ini sender ptm untuk yg pert...
# ..                                                 ...
# 995  ya tuhan besok sekolah agama offline aku gamau...
# 996  bukan sih tapi udh mau zona ijo katanya semoga...
# 997  san nanti pulang sekolah ya aku lagi ngajar of...
# 998                          males bgt sekolah offline
# 999  bener banget aku dulu waktu masih sekolah offl...
#
#                                            tweet_clean  \
# 0        astagaaaa baru inget sekarang sekolah offline
# 1    yg udh sekolah offline lama lama bosan gsi sek...
# 2             wah udah sekolah offline semangat jojooo
# 3    unty haii juga yuk yg sekolah offline kayak ak...
# 4    sch hai gais hari ini sender ptm untuk yg pert...
# ..                                                 ...
# 995  ya tuhan besok sekolah agama offline aku gamau...
# 996  bukan sih tapi udh mau zona ijo katanya semoga...
# 997  san nanti pulang sekolah ya aku lagi ngajar of...
# 998                          males bgt sekolah offline
# 999  bener banget aku dulu waktu masih sekolah offl...
#
#                                       tweet_clean_alay  \
# 0           astaga baru ingat sekarang sekolah offline
# 1    yang sudah sekolah offline lama lama bosan tid...
# 2            wah sudah sekolah offline semangat jojooo
# 3    unty hai juga yuk yang sekolah offline kayak a...
# 4    sch hai gais hari ini sender ptm untuk yang pe...
# ..                                                 ...
# 995  ya tuhan besok sekolah agama offline aku tidak...
# 996  bukan sih tapi sudah mau zona hijau katanya se...
# 997  san nanti pulang sekolah ya aku lagi mengajar ...
# 998                       malas banget sekolah offline
# 999  benar banget aku dulu waktu masih sekolah offl...
#
#                                            tweet_token  \
# 0    [astaga, baru, ingat, sekarang, sekolah, offline]
# 1    [yang, sudah, sekolah, offline, lama, lama, bo...
# 2     [wah, sudah, sekolah, offline, semangat, jojooo]
# 3    [unty, hai, juga, yuk, yang, sekolah, offline,...
# 4    [sch, hai, gais, hari, ini, sender, ptm, untuk...
# ..                                                 ...
# 995  [ya, tuhan, besok, sekolah, agama, offline, ak...
# 996  [bukan, sih, tapi, sudah, mau, zona, hijau, ka...
# 997  [san, nanti, pulang, sekolah, ya, aku, lagi, m...
# 998                  [malas, banget, sekolah, offline]
# 999  [benar, banget, aku, dulu, waktu, masih, sekol...
#
#                                         tweet_stopword  \
# 0                           [astaga, sekolah, offline]
# 1    [sekolah, offline, bosan, sekolah, offline, gu...
# 2                 [sekolah, offline, semangat, jojooo]
# 3    [unty, hai, yuk, sekolah, offline, kayak, sema...
# 4    [sch, hai, gais, sender, ptm, kali, sekolah, a...
# ..                                                 ...
# 995  [tuhan, besok, sekolah, agama, offline, presen...
# 996       [zona, hijau, semoga, dom, sekolah, offline]
# 997          [san, pulang, sekolah, mengajar, offline]
# 998                  [malas, banget, sekolah, offline]
# 999  [banget, sekolah, offline, sarapan, perut, ena...
#
#                                      tweet_normalisasi  \
# 0                           [astaga, sekolah, offline]
# 1    [sekolah, offline, bosan, sekolah, offline, sa...
# 2                 [sekolah, offline, semangat, jojooo]
# 3    [unty, hai, yuk, sekolah, offline, kayak, sema...
# 4    [sch, hai, teman teman, sender, ptm, kali, sek...
# ..                                                 ...
# 995  [tuhan, besok, sekolah, agama, offline, presen...
# 996       [zona, hijau, semoga, dom, sekolah, offline]
# 997          [san, pulang, sekolah, mengajar, offline]
# 998                  [malas, banget, sekolah, offline]
# 999  [banget, sekolah, offline, sarapan, perut, ena...
#
#                                         tweet_stemming  \
# 0                     ['astaga', 'sekolah', 'offline']
# 1    ['sekolah', 'offline', 'bosan', 'sekolah', 'of...
# 2         ['sekolah', 'offline', 'semangat', 'jojooo']
# 3    ['unty', 'hai', 'yuk', 'sekolah', 'offline', '...
# 4    ['sch', 'hai', 'teman teman', 'sender', 'ptm',...
# ..                                                 ...
# 995  ['tuhan', 'besok', 'sekolah', 'agama', 'offlin...
# 996  ['zona', 'hijau', 'moga', 'dom', 'sekolah', 'o...
# 997    ['san', 'pulang', 'sekolah', 'ajar', 'offline']
# 998          ['malas', 'banget', 'sekolah', 'offline']
# 999  ['banget', 'sekolah', 'offline', 'sarap', 'per...
#
#                                           tweet_bersih
# 0                               astaga sekolah offline
# 1     sekolah offline bosan sekolah offline saya bosan
# 2                      sekolah offline semangat jojooo
# 3    unty hai yuk sekolah offline kayak semangat aj...
# 4    sch hai teman teman sender ptm kali sekolah al...
# ..                                                 ...
# 995       tuhan besok sekolah agama offline presentasi
# 996                zona hijau moga dom sekolah offline
# 997                    san pulang sekolah ajar offline
# 998                       malas banget sekolah offline
# 999  banget sekolah offline sarap perut enak makan ...
#
# [1000 rows x 12 columns]

# %%
filename = 'dataset/dataset-preprocessing.csv'
data_twt.to_csv(filename, columns=['tweet_bersih', 'label_sentimen'], index=False)
